# %% [markdown]
# <a href="https://colab.research.google.com/github/081u9/115-1/blob/main/411414965_h2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("請輸入目前金幣數量:"))
y=int(input("請輸入獲得金幣數量:"))
print(f"任務完成！你現在有{x+y}枚金幣")
# Out:
# 請輸入目前金幣數量:200
# 請輸入獲得金幣數量:5
# 任務完成！你現在有205枚金幣
