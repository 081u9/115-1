# %% [markdown]
# <a href="https://colab.research.google.com/github/081u9/115-1/blob/main/411414965_h1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
print("hello","hello")
# Out:
# hello hello

# %%
a=5
b=2.5
c="Python"
print(type(a))
# Out:
# <class 'int'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=5
h=5
print(id(t))
# Out:
# 10446536

# %%
print(50000 * (1 + 0.015) ** 5)
# Out:
# 53864.20019421873
